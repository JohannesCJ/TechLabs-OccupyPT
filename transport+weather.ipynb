# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#importing dataset from csv file

transport= pd.read_csv("Nov09JnyExport.csv")
transport
# Out:
#          downo daytype SubSystem                        StartStn  \
# 0            3     Tue       LUL                       Unstarted
# 1            4     Wed       LUL                       Unstarted
# 2            3     Tue        NR                       Unstarted
# 3            4     Wed        NR                       Unstarted
# 4            6     Fri        NR                       Unstarted
# ...        ...     ...       ...                             ...
# 2623482      7     Sat      TRAM  GEORGE STRT TRAM
# 2623483      3     Tue       LUL                       Wood Lane
# 2623484      6     Fri       LUL              Tottenham Court Rd
# 2623485      7     Sat       LTB                             Bus
# 2623486      6     Fri       LTB                             Bus
#
#                   EndStation  EntTime EntTimeHHMM  ExTime EXTimeHHMM    ZVPPT  \
# 0              Kings Cross M        0       00:00     633      10:33    Z0104
# 1               Sudbury Hill        0       00:00     447      07:27    Z0110
# 2                   Richmond        0       00:00     966      16:06    Z0304
# 3                    Romford        0       00:00     657      10:57    Z0110
# 4        Norwood Junction SR        0       00:00     450      07:30    Z0104
# ...                      ...      ...         ...     ...        ...      ...
# 2623482            Wimbledon      999       16:39    1025      17:05  -------
# 2623483         Baker Street      999       16:39    1019      16:59    Z0102
# 2623484                 Oval      999       16:39    1016      16:56  -------
# 2623485                  Bus      999       16:39       0      00:00    Z0203
# 2623486                  Bus      999       16:39       0      00:00    B0104
#
#         JNYTYP DailyCapping  FFare  DFare RouteID  \
# 0          TKT            N      0      0      XX
# 1          TKT            N      0      0      XX
# 2          TKT            N      0      0      XX
# 3          TKT            N      0      0      XX
# 4          TKT            N      0      0      XX
# ...        ...          ...    ...    ...     ...
# 2623482    PPY            N      0      0      XX
# 2623483    TKT            N      0      0      XX
# 2623484    PPY            N    220    220      XX
# 2623485    TKT            N      0      0     262
# 2623486    TKT            N      0      0      55
#
#                          FinalProduct
# 0                LUL Travelcard-7 Day
# 1              Freedom Pass (Elderly)
# 2                LUL Travelcard-7 Day
# 3              Freedom Pass (Elderly)
# 4                LUL Travelcard-7 Day
# ...                               ...
# 2623482                          PAYG
# 2623483        LUL Travelcard-1 Month
# 2623484                          PAYG
# 2623485          LUL Travelcard-7 Day
# 2623486  Bus & Tram Pass (Child Free)
#
# [2623487 rows x 16 columns]

# %%
transport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2623487 entries, 0 to 2623486
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   downo         int64
#  1   daytype       object
#  2   SubSystem     object
#  3   StartStn      object
#  4   EndStation    object
#  5   EntTime       int64
#  6   EntTimeHHMM   object
#  7   ExTime        int64
#  8   EXTimeHHMM    object
#  9   ZVPPT         object
#  10  JNYTYP        object
#  11  DailyCapping  object
#  12  FFare         int64
#  13  DFare         int64
#  14  RouteID       object
#  15  FinalProduct  object
# dtypes: int64(5), object(11)
# memory usage: 320.2+ MB

# %%
transport.drop(["downo","ZVPPT","JNYTYP","DailyCapping","FFare","DFare","FinalProduct"],axis=1, inplace=True)
print(transport.head(10))
# Out:
#   daytype SubSystem   StartStn           EndStation  EntTime EntTimeHHMM  \
# 0     Tue       LUL  Unstarted        Kings Cross M        0       00:00
# 1     Wed       LUL  Unstarted         Sudbury Hill        0       00:00
# 2     Tue        NR  Unstarted             Richmond        0       00:00
# 3     Wed        NR  Unstarted              Romford        0       00:00
# 4     Fri        NR  Unstarted  Norwood Junction SR        0       00:00
# 5     Fri       LUL  Unstarted       Clapham Common        0       00:00
# 6     Thu        NR  Unstarted  Norwood Junction SR        0       00:00
# 7     Thu        NR  Unstarted              Norbury        0       00:00
# 8     Thu       LUL  Unstarted       Clapham Common        0       00:00
# 9     Mon       LUL  Unstarted        Kings Cross M        0       00:00
#
#    ExTime EXTimeHHMM RouteID
# 0     633      10:33      XX
# 1     447      07:27      XX
# 2     966      16:06      XX
# 3     657      10:57      XX
# 4     450      07:30      XX
# 5     439      07:19      XX
# 6     454      07:34      XX
# 7     955      15:55      XX
# 8     431      07:11      XX
# 9     498      08:18      XX

# %%
transport = transport.rename(columns={ 'daytype': 'DayType', 'EndStation': 'EndStn',
                        'EXTimeHHMM': 'ExTimeHHMM',})

# %%
transport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2623487 entries, 0 to 2623486
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   DayType      object
#  1   SubSystem    object
#  2   StartStn     object
#  3   EndStn       object
#  4   EntTime      int64
#  5   EntTimeHHMM  object
#  6   ExTime       int64
#  7   ExTimeHHMM   object
#  8   RouteID      object
# dtypes: int64(2), object(7)
# memory usage: 180.1+ MB

# %%
unstarted = transport[ transport['StartStn'] == "Unstarted" ].index 
unended = transport[ transport['EndStn'] == "Unended" ].index 
#route = transport[ transport['RouteID'] == "XX" ].index

# %%
#dropping stations with no start and end
transport.drop(unstarted, inplace = True) 
transport.drop(unended, inplace = True) 
#transport.drop(route, inplace = True) 
transport
# Out:
#         DayType SubSystem                        StartStn        EndStn  \
# 45989       Mon       LUL                   Goodge Street    Totteridge
# 45990       Fri       LTB                             Bus           Bus
# 45991       Thu       LTB                             Bus           Bus
# 45992       Fri       LTB                             Bus           Bus
# 45993       Sat       LTB                             Bus           Bus
# ...         ...       ...                             ...           ...
# 2623482     Sat      TRAM  GEORGE STRT TRAM                   Wimbledon
# 2623483     Tue       LUL                       Wood Lane  Baker Street
# 2623484     Fri       LUL              Tottenham Court Rd          Oval
# 2623485     Sat       LTB                             Bus           Bus
# 2623486     Fri       LTB                             Bus           Bus
#
#          EntTime EntTimeHHMM  ExTime ExTimeHHMM RouteID
# 45989       1000       16:40    1041      17:21      XX
# 45990       1000       16:40       0      00:00     242
# 45991       1000       16:40       0      00:00      16
# 45992       1000       16:40       0      00:00     254
# 45993       1000       16:40       0      00:00     474
# ...          ...         ...     ...        ...     ...
# 2623482      999       16:39    1025      17:05      XX
# 2623483      999       16:39    1019      16:59      XX
# 2623484      999       16:39    1016      16:56      XX
# 2623485      999       16:39       0      00:00     262
# 2623486      999       16:39       0      00:00      55
#
# [2577493 rows x 9 columns]

# %%
print(sorted(transport['RouteID'].unique()))
# Out:
# ['1', '10', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '12', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '13', '131', '132', '133', '134', '135', '136', '137', '138', '139', '14', '140', '141', '142', '143', '143D', '144', '145', '146', '147', '148', '149', '15', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '15H', '16', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '17', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '18', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '19', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '2', '20', '200', '201', '202', '203', '204', '205', '206', '207', '208', '209', '21', '210', '211', '212', '213', '214', '215', '216', '217', '219', '22', '220', '221', '222', '223', '224', '225', '226', '227', '228', '229', '23', '230', '231', '232', '233', '234', '235', '236', '237', '238', '24', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '25', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '26', '260', '261', '262', '263', '264', '265', '266', '267', '268', '269', '27', '270', '271', '272', '273', '274', '275', '276', '277', '279', '28', '280', '281', '281R', '282', '283', '284', '285', '286', '287', '288', '289', '29', '290', '291', '292', '293', '294', '295', '296', '297', '298', '299', '2U', '3', '30', '300', '302', '303', '305', '307', '308', '309', '31', '312', '313', '315', '316', '317', '318', '319', '32', '320', '321', '322', '323', '325', '326', '327', '328', '329', '33', '330', '331', '332', '333', '336', '337', '339', '34', '340', '341', '343', '344', '345', '346', '347', '349', '35', '350', '352', '353', '354', '355', '356', '357', '358', '359', '36', '360', '362', '363', '364', '365', '366', '367', '368', '369', '37', '370', '370D', '371', '372', '375', '376', '377', '379', '38', '380', '381', '382', '383', '384', '385', '386', '387', '388', '389', '39', '390', '391', '393', '394', '395', '396', '397', '398', '399', '4', '40', '401', '403', '404', '405', '405D', '406', '407', '41', '410', '411', '412', '413', '414', '415', '417', '418', '419', '42', '422', '423', '424', '425', '427', '428', '43', '430', '432', '434', '436', '44', '440', '444', '45', '450', '452', '453', '455', '46', '460', '462', '463', '464', '465', '466', '467', '468', '469', '47', '470', '472', '473', '474', '476', '48', '481', '482', '484', '485', '486', '487', '488', '49', '490', '491', '492', '493', '496', '498', '499', '5', '50', '507', '51', '52', '521', '53', '54', '549', '55', '56', '57', '58', '59', '6', '60', '601', '602', '603', '605', '606', '607', '608', '609', '61', '611', '612', '613', '614', '616', '617', '62', '621', '624', '625', '626', '627', '628', '629', '63', '632', '634', '635', '636', '637', '638', '639', '64', '640', '641', '642', '643', '646', '647', '648', '649', '65', '650', '651', '652', '653', '654', '655', '656', '657', '658', '66', '660', '661', '664', '665', '667', '669', '66U', '67', '671', '672', '673', '674', '675', '678', '679', '68', '681', '683', '685', '686', '687', '688', '689', '69', '690', '691', '692', '696', '697', '698', '699', '7', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '8', '80', '81', '82', '83', '84', '85', '86', '86U', '87', '88', '89', '9', '90', '91', '92', '93', '94', '95', '953', '96', '969', '97', '98', '99', '9H', 'A10', 'B11', 'B12', 'B13', 'B14', 'B15', 'B16', 'C1', 'C10', 'C10D', 'C11', 'C2', 'C3', 'D3', 'D6', 'D7', 'D8', 'E1', 'E10', 'E11', 'E2', 'E3', 'E5', 'E6', 'E7', 'E8', 'E9', 'ELW', 'G1', 'H1', 'H10', 'H11', 'H12', 'H13', 'H14', 'H17', 'H18', 'H19', 'H2', 'H20', 'H22', 'H25', 'H26', 'H28', 'H3', 'H32', 'H37', 'H9', 'H91', 'H98', 'K1', 'K2', 'K3', 'K4', 'K5', 'LBN', 'N1', 'N10', 'N102', 'N105', 'N108', 'N11', 'N111', 'N119', 'N12', 'N128', 'N13', ' ...

# %%
transport['RouteID'].value_counts()
# Out:
# XX     809413
# 86      12066
# 25      11170
# 36      10606
# 254     10526
#         ...
# 689         1
# 969         1
# 665         1
# LBN         1
# 632         1
# Name: RouteID, Length: 745, dtype: int64

# %%
print(sorted(transport['SubSystem'].unique()))
# Out:
# ['DLR', 'DLR/LRC', 'HEX', 'LRC', 'LTB', 'LUL', 'LUL/DLR', 'LUL/LRC', 'LUL/NR', 'LUL/NR/DLR', 'LUL/NR/LRC', 'LUL/TRAM', 'NR', 'NR/DLR', 'NR/LRC', 'TRAM']

# %%
transport['SubSystem'].value_counts()
# Out:
# LTB           1768080
# LUL            702843
# NR              25789
# LUL/NR          24851
# LUL/DLR         13911
# TRAM             9583
# DLR              9008
# LUL/NR/LRC       8012
# NR/LRC           5991
# LRC              3369
# LUL/LRC          3087
# LUL/NR/DLR       1865
# HEX               751
# NR/DLR            263
# LUL/TRAM           86
# DLR/LRC             4
# Name: SubSystem, dtype: int64

# %%
transport.reset_index(inplace = True)

# %%
print(transport.shape)
transport.head(40)
# Out:
# (2577493, 10)
#     index DayType SubSystem             StartStn         EndStn  EntTime  \
# 0   45989     Mon       LUL        Goodge Street     Totteridge     1000
# 1   45990     Fri       LTB                  Bus            Bus     1000
# 2   45991     Thu       LTB                  Bus            Bus     1000
# 3   45992     Fri       LTB                  Bus            Bus     1000
# 4   45993     Sat       LTB                  Bus            Bus     1000
# 5   45994     Thu       LUL         Preston Road      Northwood     1000
# 6   45995     Sat        NR               Ilford     Unfinished     1000
# 7   45996     Fri       LTB                  Bus            Bus     1000
# 8   45997     Sat       LTB                  Bus            Bus     1000
# 9   45998     Thu       LUL              Holborn   Bounds Green     1000
# 10  45999     Tue       LTB                  Bus            Bus     1000
# 11  46000     Thu       LTB                  Bus            Bus     1000
# 12  46001     Thu       LTB                  Bus            Bus     1000
# 13  46002     Mon       LTB                  Bus            Bus     1000
# 14  46003     Sun       LUL          Earls Court        Pimlico     1000
# 15  46004     Thu       LTB                  Bus            Bus     1000
# 16  46005     Tue       LUL             Victoria  Bethnal Green     1000
# 17  46006     Fri    LUL/NR  Walthamstow Central        Arsenal     1000
# 18  46007     Sun       LTB                  Bus            Bus     1000
# 19  46008     Mon       LTB                  Bus            Bus     1000
# 20  46009     Fri       LTB                  Bus            Bus     1000
# 21  46010     Fri       LTB                  Bus            Bus     1000
# 22  46011     Thu       LTB                  Bus            Bus     1000
# 23  46012     Tue       LTB                  Bus            Bus     1000
# 24  46013     Wed       LTB                  Bus            Bus     1000
# 25  46014     Sat       LTB                  Bus            Bus     1000
# 26  46015     Thu       LTB                  Bus            Bus     1000
# 27  46016     Wed       LTB                  Bus            Bus     1000
# 28  46017     Thu       LTB                  Bus            Bus     1000
# 29  46018     Wed       LTB                  Bus            Bus     1000
# 30  46019     Mon       LUL             Highbury      Stratford     1000
# 31  46020     Tue       LTB                  Bus            Bus     1000
# 32  46021     Mon       LTB                  Bus            Bus     1000
# 33  46022     Thu       LTB                  Bus            Bus     1000
# 34  46023     Sun       LTB                  Bus            Bus     1000
# 35  46024     Wed       LTB                  Bus            Bus     1000
# 36  46025     Sat       LUL           Embankment  Putney Bridge     1000
# 37  46026     Mon       LTB                  Bus            Bus     1000
# 38  46027     Tue       LTB                  Bus            Bus     1000
# 39  46028     Tue       LTB                  Bus            Bus     1000
#
#    EntTimeHHMM  ExTime ExTimeHHMM RouteID
# 0        16:40    1041      17:21      XX
# 1        16:40       0      00:00     242
# 2        16:40       0      00:00      16
# 3        16:40       0      00:00     254
# 4        16:40       0      00:00     474
# 5        16:40    1024      17:04      XX
# 6        16:40       0      00:00      XX
# 7        16:40       0      00:00      92
# 8        16:40       0      00:00     120
# 9        16:40    1028      17:08      XX
# 10       16:40       0      00:00      K1
# 11       16:40       0      00:00     313
# 12       16:40       0      00:00     259
# 13       16:40       0      00:00     237
# 14       16:40    1021      17:01      XX
# 15       16:40       0      00:00     260
# 16       16:40    1027      17:07      XX
# 17       16:40    1017      16:57      XX
# 18       16:40       0      00:00     208
# 19       16:40       0      00:00     111
# 20       16:40       0      00:00     191
# 21       16:40       0      00:00      69
# 22       16:40       0      00:00     147
# 23       16:40       0      00:00     259
# 24       16:40       0      00:00     119
# 25       16:40       0      00:00      32
# 26       16:40       0      00:00     387
# 27       16:40       0      00:00     217
# 28       16:40       0      00:00     185
# 29       16:40       0      00:00      87
# 30       16:40    1020      17:00      XX
# 31       16:40       0      00:00     213
# 32       16:40       0      00:00      14
# 33       16:40       0      00:00     211
# 34       16:40       0      00:00     253
# 35       16:40       0      00:00      15
# 36       16:40    1026      17:06      XX
# 37       16:40       0      00:00     H22
# 38       16:40       0      00:00     234
# 39       16:40       0      00:00     H17

# %%
transport['JourneyLength'] = transport['ExTime'] - transport['EntTime']
transport
# Out:
#            index DayType SubSystem                        StartStn  \
# 0          45989     Mon       LUL                   Goodge Street
# 1          45990     Fri       LTB                             Bus
# 2          45991     Thu       LTB                             Bus
# 3          45992     Fri       LTB                             Bus
# 4          45993     Sat       LTB                             Bus
# ...          ...     ...       ...                             ...
# 2577488  2623482     Sat      TRAM  GEORGE STRT TRAM
# 2577489  2623483     Tue       LUL                       Wood Lane
# 2577490  2623484     Fri       LUL              Tottenham Court Rd
# 2577491  2623485     Sat       LTB                             Bus
# 2577492  2623486     Fri       LTB                             Bus
#
#                EndStn  EntTime EntTimeHHMM  ExTime ExTimeHHMM RouteID  \
# 0          Totteridge     1000       16:40    1041      17:21      XX
# 1                 Bus     1000       16:40       0      00:00     242
# 2                 Bus     1000       16:40       0      00:00      16
# 3                 Bus     1000       16:40       0      00:00     254
# 4                 Bus     1000       16:40       0      00:00     474
# ...               ...      ...         ...     ...        ...     ...
# 2577488     Wimbledon      999       16:39    1025      17:05      XX
# 2577489  Baker Street      999       16:39    1019      16:59      XX
# 2577490          Oval      999       16:39    1016      16:56      XX
# 2577491           Bus      999       16:39       0      00:00     262
# 2577492           Bus      999       16:39       0      00:00      55
#
#          JourneyLength
# 0                   41
# 1                -1000
# 2                -1000
# 3                -1000
# 4                -1000
# ...                ...
# 2577488             26
# 2577489             20
# 2577490             17
# 2577491           -999
# 2577492           -999
#
# [2577493 rows x 11 columns]

# %%
#seperating data with subsystem=bus
bus = transport[transport['SubSystem'] == 'LTB']
bus
# Out:
#            index DayType SubSystem StartStn EndStn  EntTime EntTimeHHMM  \
# 1          45990     Fri       LTB      Bus    Bus     1000       16:40
# 2          45991     Thu       LTB      Bus    Bus     1000       16:40
# 3          45992     Fri       LTB      Bus    Bus     1000       16:40
# 4          45993     Sat       LTB      Bus    Bus     1000       16:40
# 7          45996     Fri       LTB      Bus    Bus     1000       16:40
# ...          ...     ...       ...      ...    ...      ...         ...
# 2577484  2623478     Sat       LTB      Bus    Bus      999       16:39
# 2577485  2623479     Thu       LTB      Bus    Bus      999       16:39
# 2577486  2623480     Sat       LTB      Bus    Bus      999       16:39
# 2577491  2623485     Sat       LTB      Bus    Bus      999       16:39
# 2577492  2623486     Fri       LTB      Bus    Bus      999       16:39
#
#          ExTime ExTimeHHMM RouteID  JourneyLength
# 1             0      00:00     242          -1000
# 2             0      00:00      16          -1000
# 3             0      00:00     254          -1000
# 4             0      00:00     474          -1000
# 7             0      00:00      92          -1000
# ...         ...        ...     ...            ...
# 2577484       0      00:00     120           -999
# 2577485       0      00:00     177           -999
# 2577486       0      00:00     235           -999
# 2577491       0      00:00     262           -999
# 2577492       0      00:00      55           -999
#
# [1768080 rows x 11 columns]

# %%
bus.drop(['JourneyLength','StartStn','EndStn'],axis=1,inplace=True)
bus.head()
# Out:
# C:\Users\sandr\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    index DayType SubSystem  EntTime EntTimeHHMM  ExTime ExTimeHHMM RouteID
# 1  45990     Fri       LTB     1000       16:40       0      00:00     242
# 2  45991     Thu       LTB     1000       16:40       0      00:00      16
# 3  45992     Fri       LTB     1000       16:40       0      00:00     254
# 4  45993     Sat       LTB     1000       16:40       0      00:00     474
# 7  45996     Fri       LTB     1000       16:40       0      00:00      92

# %%
bus.reset_index(inplace = True)
bus.drop('index',axis=1,inplace=True)
bus.drop('level_0',axis=1,inplace=True)
bus.to_csv('bus.csv')
# Out:
# C:\Users\sandr\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
bus
# Out:
#         DayType SubSystem  EntTime EntTimeHHMM  ExTime ExTimeHHMM RouteID
# 0           Fri       LTB     1000       16:40       0      00:00     242
# 1           Thu       LTB     1000       16:40       0      00:00      16
# 2           Fri       LTB     1000       16:40       0      00:00     254
# 3           Sat       LTB     1000       16:40       0      00:00     474
# 4           Fri       LTB     1000       16:40       0      00:00      92
# ...         ...       ...      ...         ...     ...        ...     ...
# 1768075     Sat       LTB      999       16:39       0      00:00     120
# 1768076     Thu       LTB      999       16:39       0      00:00     177
# 1768077     Sat       LTB      999       16:39       0      00:00     235
# 1768078     Sat       LTB      999       16:39       0      00:00     262
# 1768079     Fri       LTB      999       16:39       0      00:00      55
#
# [1768080 rows x 7 columns]

# %%
#seperating data with subsystem='LUL'(train)
train = transport[transport['SubSystem'] == 'LUL']
train.drop('RouteID',axis=1,inplace=True)
train.head()
# Out:
# C:\Users\sandr\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     index DayType SubSystem       StartStn         EndStn  EntTime  \
# 0   45989     Mon       LUL  Goodge Street     Totteridge     1000
# 5   45994     Thu       LUL   Preston Road      Northwood     1000
# 9   45998     Thu       LUL        Holborn   Bounds Green     1000
# 14  46003     Sun       LUL    Earls Court        Pimlico     1000
# 16  46005     Tue       LUL       Victoria  Bethnal Green     1000
#
#    EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength
# 0        16:40    1041      17:21             41
# 5        16:40    1024      17:04             24
# 9        16:40    1028      17:08             28
# 14       16:40    1021      17:01             21
# 16       16:40    1027      17:07             27

# %%
#loading london stations dataset 
stations = pd.read_csv("London stations.csv")
stations
# Out:
#                Station    OS X    OS Y   Latitude  Longitude Zone  Postcode
# 0           Abbey Road  539081  183352  51.531952   0.003723    3   E15 3NB
# 1           Abbey Wood  547297  179002  51.490784   0.120272    4   SE2 9RH
# 2        Acton Central  520613  180299  51.508758  -0.263430    2    W3 6BH
# 3      Acton Main Line  520296  181196  51.516887  -0.267690    3    W3 9EH
# 4           Acton Town  519457  179639  51.503071  -0.280303    3    W3 8HN
# ..                 ...     ...     ...        ...        ...  ...       ...
# 647      Woodside Park  525725  192564  51.617868  -0.185426    4   N12 8SE
# 648           Woolwich  543931  178994  51.491578   0.071819    4       NaN
# 649   Woolwich Arsenal  543754  178803  51.489907   0.069194    4  SE18 6HX
# 650  Woolwich Dockyard  542738  178908  51.491108   0.054612    3  SE18 5JY
# 651     Worcester Park  522192  166133  51.381104  -0.245575    4   KT4 7ND
#
# [652 rows x 7 columns]

# %%
stations.drop(['OS X','OS Y','Zone','Postcode'],axis=1,inplace=True)
stations.head()
# Out:
#            Station   Latitude  Longitude
# 0       Abbey Road  51.531952   0.003723
# 1       Abbey Wood  51.490784   0.120272
# 2    Acton Central  51.508758  -0.263430
# 3  Acton Main Line  51.516887  -0.267690
# 4       Acton Town  51.503071  -0.280303

# %%
#combining latitude and longitude values for start station
combined = pd.merge(train,stations,left_on='StartStn',right_on='Station')
combined
# Out:
#           index DayType SubSystem          StartStn         EndStn  EntTime  \
# 0         45989     Mon       LUL     Goodge Street     Totteridge     1000
# 1         46126     Wed       LUL     Goodge Street  Charing Cross     1000
# 2         46532     Mon       LUL     Goodge Street    Camden Town     1000
# 3         47138     Tue       LUL     Goodge Street  Golders Green     1000
# 4         47304     Wed       LUL     Goodge Street         Balham     1000
# ...         ...     ...       ...               ...            ...      ...
# 617116  2093369     Sun       LUL  Clapham Junction     Unfinished      819
# 617117   481623     Fri       LUL     Tower Gateway     Unfinished     1121
# 617118  2006076     Fri       LUL        South Quay     Unfinished      783
# 617119  2223731     Tue       LUL    Island Gardens     Unfinished      873
# 617120  2266098     Tue       LUL        All Saints     Unfinished      890
#
#        EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength           Station  \
# 0            16:40    1041      17:21             41     Goodge Street
# 1            16:40    1010      16:50             10     Goodge Street
# 2            16:40    1014      16:54             14     Goodge Street
# 3            16:40    1021      17:01             21     Goodge Street
# 4            16:40    1034      17:14             34     Goodge Street
# ...            ...     ...        ...            ...               ...
# 617116       13:39       0      00:00           -819  Clapham Junction
# 617117       18:41       0      00:00          -1121     Tower Gateway
# 617118       13:03       0      00:00           -783        South Quay
# 617119       14:33       0      00:00           -873    Island Gardens
# 617120       14:50       0      00:00           -890        All Saints
#
#          Latitude  Longitude
# 0       51.520613  -0.134808
# 1       51.520613  -0.134808
# 2       51.520613  -0.134808
# 3       51.520613  -0.134808
# 4       51.520613  -0.134808
# ...           ...        ...
# 617116  51.464367  -0.170315
# 617117  51.510393  -0.074410
# 617118  51.500864  -0.018461
# 617119  51.487950  -0.010493
# 617120  51.510477  -0.012625
#
# [617121 rows x 13 columns]

# %%
combined.drop(['index','Station'],axis=1,inplace=True)

# %%
combined = combined.rename(columns={'Latitude': 'StartLat', 'Longitude': 'StartLong'})
combined
# Out:
#        DayType SubSystem          StartStn         EndStn  EntTime  \
# 0          Mon       LUL     Goodge Street     Totteridge     1000
# 1          Wed       LUL     Goodge Street  Charing Cross     1000
# 2          Mon       LUL     Goodge Street    Camden Town     1000
# 3          Tue       LUL     Goodge Street  Golders Green     1000
# 4          Wed       LUL     Goodge Street         Balham     1000
# ...        ...       ...               ...            ...      ...
# 617116     Sun       LUL  Clapham Junction     Unfinished      819
# 617117     Fri       LUL     Tower Gateway     Unfinished     1121
# 617118     Fri       LUL        South Quay     Unfinished      783
# 617119     Tue       LUL    Island Gardens     Unfinished      873
# 617120     Tue       LUL        All Saints     Unfinished      890
#
#        EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong
# 0            16:40    1041      17:21             41  51.520613  -0.134808
# 1            16:40    1010      16:50             10  51.520613  -0.134808
# 2            16:40    1014      16:54             14  51.520613  -0.134808
# 3            16:40    1021      17:01             21  51.520613  -0.134808
# 4            16:40    1034      17:14             34  51.520613  -0.134808
# ...            ...     ...        ...            ...        ...        ...
# 617116       13:39       0      00:00           -819  51.464367  -0.170315
# 617117       18:41       0      00:00          -1121  51.510393  -0.074410
# 617118       13:03       0      00:00           -783  51.500864  -0.018461
# 617119       14:33       0      00:00           -873  51.487950  -0.010493
# 617120       14:50       0      00:00           -890  51.510477  -0.012625
#
# [617121 rows x 11 columns]

# %%
combined = combined[(combined['StartStn'] != 'Unstarted') & (combined['EndStn'] != 'Unfinished')]

# %%
#combining latitude and longitude values for end station
combined = pd.merge(combined,stations,left_on='EndStn',right_on='Station')
combined.head()
# Out:
#   DayType SubSystem       StartStn         EndStn  EntTime EntTimeHHMM  \
# 0     Wed       LUL  Goodge Street  Charing Cross     1000       16:40
# 1     Fri       LUL  Goodge Street  Charing Cross     1000       16:40
# 2     Wed       LUL  Goodge Street  Charing Cross     1004       16:44
# 3     Mon       LUL  Goodge Street  Charing Cross     1005       16:45
# 4     Thu       LUL  Goodge Street  Charing Cross     1006       16:46
#
#    ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong        Station  \
# 0    1010      16:50             10  51.520613  -0.134808  Charing Cross
# 1    1011      16:51             11  51.520613  -0.134808  Charing Cross
# 2    1013      16:53              9  51.520613  -0.134808  Charing Cross
# 3    1013      16:53              8  51.520613  -0.134808  Charing Cross
# 4    1014      16:54              8  51.520613  -0.134808  Charing Cross
#
#     Latitude  Longitude
# 0  51.508359  -0.124803
# 1  51.508359  -0.124803
# 2  51.508359  -0.124803
# 3  51.508359  -0.124803
# 4  51.508359  -0.124803

# %%
combined.drop('Station',axis=1,inplace=True)
combined = combined.rename(columns={'Latitude': 'EndLat', 'Longitude': 'EndLong'})
combined
# Out:
#        DayType SubSystem       StartStn         EndStn  EntTime EntTimeHHMM  \
# 0          Wed       LUL  Goodge Street  Charing Cross     1000       16:40
# 1          Fri       LUL  Goodge Street  Charing Cross     1000       16:40
# 2          Wed       LUL  Goodge Street  Charing Cross     1004       16:44
# 3          Mon       LUL  Goodge Street  Charing Cross     1005       16:45
# 4          Thu       LUL  Goodge Street  Charing Cross     1006       16:46
# ...        ...       ...            ...            ...      ...         ...
# 521651     Wed       LUL        Croxley        Croxley     1048       17:28
# 521652     Sat       LUL        Croxley        Croxley     1105       18:25
# 521653     Tue       LUL    Chorleywood        Croxley     1007       16:47
# 521654     Wed       LUL    Chorleywood        Croxley     1113       18:33
# 521655     Tue       LUL    West Harrow        Croxley      686       11:26
#
#         ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong     EndLat  \
# 0         1010      16:50             10  51.520613  -0.134808  51.508359
# 1         1011      16:51             11  51.520613  -0.134808  51.508359
# 2         1013      16:53              9  51.520613  -0.134808  51.508359
# 3         1013      16:53              8  51.520613  -0.134808  51.508359
# 4         1014      16:54              8  51.520613  -0.134808  51.508359
# ...        ...        ...            ...        ...        ...        ...
# 521651    1048      17:28              0  51.647005  -0.441604  51.647005
# 521652    1216      20:16            111  51.647005  -0.441604  51.647005
# 521653    1034      17:14             27  51.654266  -0.518334  51.647005
# 521654    1131      18:51             18  51.654266  -0.518334  51.647005
# 521655     721      12:01             35  51.578924  -0.353847  51.647005
#
#          EndLong
# 0      -0.124803
# 1      -0.124803
# 2      -0.124803
# 3      -0.124803
# 4      -0.124803
# ...          ...
# 521651 -0.441604
# 521652 -0.441604
# 521653 -0.441604
# 521654 -0.441604
# 521655 -0.441604
#
# [521656 rows x 13 columns]

# %%
#exporting the combined dataset
combined.to_csv('combined_train.csv')

# %%
weather = pd.read_excel('weatherdata_30min.xlsx', parse_dates={'datetime':[0,1]})
weather.rename(columns={'Dew Point':'DewPoint'})
weather['Temperature'] = weather['Temperature'].str.replace('F','')
weather['Dew Point'] = weather['Dew Point'].str.replace('F','')
weather['Humidity'] = weather['Humidity'].str.replace('%','')
weather['Wind Speed'] = weather['Wind Speed'].str.replace('mph','')
weather['Wind Gust'] = weather['Wind Gust'].str.replace('mph','')
weather['Pressure'] = weather['Pressure'].str.replace('in','')
weather.drop(labels='Preciption', axis=1, inplace=True)
weather.head()
# Out:
#              datetime Temperature Dew Point Humidity  Wind Wind Speed  \
# 0 2009-11-01 00:20:00         55        52       88     SW         7
# 1 2009-11-01 00:50:00         54        52       94    WSW         3
# 2 2009-11-01 01:20:00         54        50       88    SSE         2
# 3 2009-11-01 01:50:00         52        50       94   CALM         0
# 4 2009-11-01 02:20:00         52        50       94   CALM         0
#
#   Wind Gust Pressure      Condition
# 0        0    30.07   Mostly Cloudy
# 1        0    30.07   Mostly Cloudy
# 2        0    30.04            Fair
# 3        0    30.01            Fair
# 4        0    30.01            Fair

# %%
weather = weather.astype({'Humidity':'float64','Wind Speed':'float64','Wind Gust':'float64', 'Temperature':'float64', 'Dew Point':'float64', 'Pressure':'float64'})
weather.dtypes
# Out:
# datetime       datetime64[ns]
# Temperature           float64
# Dew Point             float64
# Humidity              float64
# Wind                   object
# Wind Speed            float64
# Wind Gust             float64
# Pressure              float64
# Condition              object
# dtype: object

# %%
weather.rename(columns={'Temperature':'Temperature [F]', 'Dew Point':'DewPoint [F]'}, inplace=True)
weather.head()
# Out:
#              datetime  Temperature [F]  DewPoint [F]  Humidity  Wind  \
# 0 2009-11-01 00:20:00             55.0          52.0      88.0    SW
# 1 2009-11-01 00:50:00             54.0          52.0      94.0   WSW
# 2 2009-11-01 01:20:00             54.0          50.0      88.0   SSE
# 3 2009-11-01 01:50:00             52.0          50.0      94.0  CALM
# 4 2009-11-01 02:20:00             52.0          50.0      94.0  CALM
#
#    Wind Speed  Wind Gust  Pressure      Condition
# 0         7.0        0.0     30.07  Mostly Cloudy
# 1         3.0        0.0     30.07  Mostly Cloudy
# 2         2.0        0.0     30.04           Fair
# 3         0.0        0.0     30.01           Fair
# 4         0.0        0.0     30.01           Fair

# %%
weather['Temperature[°C]'] = round((weather['Temperature [F]']-32)*5/9, 2)
weather['DewPoint[°C]'] = round((weather['DewPoint [F]']-32)*5/9, 2)
weather.dtypes
# Out:
# datetime           datetime64[ns]
# Temperature [F]           float64
# DewPoint [F]              float64
# Humidity                  float64
# Wind                       object
# Wind Speed                float64
# Wind Gust                 float64
# Pressure                  float64
# Condition                  object
# Temperature[°C]           float64
# DewPoint[°C]              float64
# dtype: object

# %%
weather_h = weather.set_index('datetime').resample('h').mean()
weather_h.reset_index(inplace=True)
weather_h.head()
# Out:
#              datetime  Temperature [F]  DewPoint [F]  Humidity  Wind Speed  \
# 0 2009-11-01 00:00:00             54.5          52.0      91.0         5.0
# 1 2009-11-01 01:00:00             53.0          50.0      91.0         1.0
# 2 2009-11-01 02:00:00             52.0          50.0      94.0         1.5
# 3 2009-11-01 03:00:00             52.0          50.0      94.0         4.0
# 4 2009-11-01 04:00:00             52.0          50.0      94.0         4.5
#
#    Wind Gust  Pressure  Temperature[°C]  DewPoint[°C]
# 0        0.0    30.070           12.500         11.11
# 1        0.0    30.025           11.665         10.00
# 2        0.0    29.995           11.110         10.00
# 3        0.0    29.970           11.110         10.00
# 4        0.0    29.915           11.110         10.00

# %%
rainfall = pd.read_excel('UK_hourly_rainfall_Nov09.xlsx', skiprows=3, header=None, names=['Date','Rainfall', 'end'], parse_dates=[1])
rainfall.drop(labels='end', axis=1, inplace=True)

# %%
weather_compl = weather_h.merge(rainfall, left_on='datetime', right_on='Date')
weather_compl.drop('Date', axis=1, inplace=True)
weather_compl.head()
# Humidity in %, WindSpeed/Gust in mph, Pressure in in, Rainfall in mm
# Out:
#              datetime  Temperature [F]  DewPoint [F]  Humidity  Wind Speed  \
# 0 2009-11-01 00:00:00             54.5          52.0      91.0         5.0
# 1 2009-11-01 01:00:00             53.0          50.0      91.0         1.0
# 2 2009-11-01 02:00:00             52.0          50.0      94.0         1.5
# 3 2009-11-01 03:00:00             52.0          50.0      94.0         4.0
# 4 2009-11-01 04:00:00             52.0          50.0      94.0         4.5
#
#    Wind Gust  Pressure  Temperature[°C]  DewPoint[°C]  Rainfall
# 0        0.0    30.070           12.500         11.11       0.0
# 1        0.0    30.025           11.665         10.00       0.0
# 2        0.0    29.995           11.110         10.00       0.0
# 3        0.0    29.970           11.110         10.00       0.0
# 4        0.0    29.915           11.110         10.00       0.0

# %%
weather_compl
# Out:
#                datetime  Temperature [F]  DewPoint [F]  Humidity  Wind Speed  \
# 0   2009-11-01 00:00:00             54.5          52.0      91.0         5.0
# 1   2009-11-01 01:00:00             53.0          50.0      91.0         1.0
# 2   2009-11-01 02:00:00             52.0          50.0      94.0         1.5
# 3   2009-11-01 03:00:00             52.0          50.0      94.0         4.0
# 4   2009-11-01 04:00:00             52.0          50.0      94.0         4.5
# ..                  ...              ...           ...       ...         ...
# 177 2009-11-07 20:00:00             46.0          39.0      76.0         8.5
# 178 2009-11-07 21:00:00             45.5          39.0      78.5         7.5
# 179 2009-11-07 21:00:00             45.5          39.0      78.5         7.5
# 180 2009-11-07 22:00:00             45.5          40.0      81.0         6.5
# 181 2009-11-07 23:00:00             45.0          41.0      87.0         5.0
#
#      Wind Gust  Pressure  Temperature[°C]  DewPoint[°C]  Rainfall
# 0          0.0    30.070           12.500        11.110       0.0
# 1          0.0    30.025           11.665        10.000       0.0
# 2          0.0    29.995           11.110        10.000       0.0
# 3          0.0    29.970           11.110        10.000       0.0
# 4          0.0    29.915           11.110        10.000       0.0
# ..         ...       ...              ...           ...       ...
# 177        0.0    29.340            7.780         3.890       0.0
# 178        0.0    29.340            7.500         3.890       0.0
# 179        0.0    29.340            7.500         3.890       0.0
# 180        0.0    29.340            7.500         4.445       0.0
# 181        0.0    29.340            7.220         5.000       0.2
#
# [182 rows x 10 columns]

# %%
import datetime
import calendar

day_abbr = ["Mon","Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

def date_day(x): 
    day = datetime.datetime.strptime(str(x["datetime"]), '%Y-%m-%d %H:%M:%S')
    return day_abbr[day.weekday()]

weather_compl['DayType'] = weather_compl.apply(date_day, axis = 1) 

def date_HH(x): 
    day = datetime.datetime.strptime(str(x["datetime"]), '%Y-%m-%d %H:%M:%S')
    return day.strftime("%H")

weather_compl['HH'] = weather_compl.apply(date_HH, axis = 1)

# %%
transport["HH"] = transport["EntTimeHHMM"].str[0:2]
transport.head()
# Out:
#    index DayType SubSystem       StartStn      EndStn  EntTime EntTimeHHMM  \
# 0  45989     Mon       LUL  Goodge Street  Totteridge     1000       16:40
# 1  45990     Fri       LTB            Bus         Bus     1000       16:40
# 2  45991     Thu       LTB            Bus         Bus     1000       16:40
# 3  45992     Fri       LTB            Bus         Bus     1000       16:40
# 4  45993     Sat       LTB            Bus         Bus     1000       16:40
#
#    ExTime ExTimeHHMM RouteID  JourneyLength  HH
# 0    1041      17:21      XX             41  16
# 1       0      00:00     242          -1000  16
# 2       0      00:00      16          -1000  16
# 3       0      00:00     254          -1000  16
# 4       0      00:00     474          -1000  16

# %%
train= pd.read_csv("combined_train.csv")
train
# Out:
#         Unnamed: 0 DayType SubSystem       StartStn         EndStn  EntTime  \
# 0                0     Wed       LUL  Goodge Street  Charing Cross     1000
# 1                1     Fri       LUL  Goodge Street  Charing Cross     1000
# 2                2     Wed       LUL  Goodge Street  Charing Cross     1004
# 3                3     Mon       LUL  Goodge Street  Charing Cross     1005
# 4                4     Thu       LUL  Goodge Street  Charing Cross     1006
# ...            ...     ...       ...            ...            ...      ...
# 521651      521651     Wed       LUL        Croxley        Croxley     1048
# 521652      521652     Sat       LUL        Croxley        Croxley     1105
# 521653      521653     Tue       LUL    Chorleywood        Croxley     1007
# 521654      521654     Wed       LUL    Chorleywood        Croxley     1113
# 521655      521655     Tue       LUL    West Harrow        Croxley      686
#
#        EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong  \
# 0            16:40    1010      16:50             10  51.520613  -0.134808
# 1            16:40    1011      16:51             11  51.520613  -0.134808
# 2            16:44    1013      16:53              9  51.520613  -0.134808
# 3            16:45    1013      16:53              8  51.520613  -0.134808
# 4            16:46    1014      16:54              8  51.520613  -0.134808
# ...            ...     ...        ...            ...        ...        ...
# 521651       17:28    1048      17:28              0  51.647005  -0.441604
# 521652       18:25    1216      20:16            111  51.647005  -0.441604
# 521653       16:47    1034      17:14             27  51.654266  -0.518334
# 521654       18:33    1131      18:51             18  51.654266  -0.518334
# 521655       11:26     721      12:01             35  51.578924  -0.353847
#
#            EndLat   EndLong
# 0       51.508359 -0.124803
# 1       51.508359 -0.124803
# 2       51.508359 -0.124803
# 3       51.508359 -0.124803
# 4       51.508359 -0.124803
# ...           ...       ...
# 521651  51.647005 -0.441604
# 521652  51.647005 -0.441604
# 521653  51.647005 -0.441604
# 521654  51.647005 -0.441604
# 521655  51.647005 -0.441604
#
# [521656 rows x 14 columns]

# %%
train["HH"] = train["EntTimeHHMM"].str[0:2]
train.head()
# Out:
#    Unnamed: 0 DayType SubSystem       StartStn         EndStn  EntTime  \
# 0           0     Wed       LUL  Goodge Street  Charing Cross     1000
# 1           1     Fri       LUL  Goodge Street  Charing Cross     1000
# 2           2     Wed       LUL  Goodge Street  Charing Cross     1004
# 3           3     Mon       LUL  Goodge Street  Charing Cross     1005
# 4           4     Thu       LUL  Goodge Street  Charing Cross     1006
#
#   EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong  \
# 0       16:40    1010      16:50             10  51.520613  -0.134808
# 1       16:40    1011      16:51             11  51.520613  -0.134808
# 2       16:44    1013      16:53              9  51.520613  -0.134808
# 3       16:45    1013      16:53              8  51.520613  -0.134808
# 4       16:46    1014      16:54              8  51.520613  -0.134808
#
#       EndLat   EndLong  HH
# 0  51.508359 -0.124803  16
# 1  51.508359 -0.124803  16
# 2  51.508359 -0.124803  16
# 3  51.508359 -0.124803  16
# 4  51.508359 -0.124803  16

# %%
weather_compl
# Out:
#                datetime  Temperature [F]  DewPoint [F]  Humidity  Wind Speed  \
# 0   2009-11-01 00:00:00             54.5          52.0      91.0         5.0
# 1   2009-11-01 01:00:00             53.0          50.0      91.0         1.0
# 2   2009-11-01 02:00:00             52.0          50.0      94.0         1.5
# 3   2009-11-01 03:00:00             52.0          50.0      94.0         4.0
# 4   2009-11-01 04:00:00             52.0          50.0      94.0         4.5
# ..                  ...              ...           ...       ...         ...
# 177 2009-11-07 20:00:00             46.0          39.0      76.0         8.5
# 178 2009-11-07 21:00:00             45.5          39.0      78.5         7.5
# 179 2009-11-07 21:00:00             45.5          39.0      78.5         7.5
# 180 2009-11-07 22:00:00             45.5          40.0      81.0         6.5
# 181 2009-11-07 23:00:00             45.0          41.0      87.0         5.0
#
#      Wind Gust  Pressure  Temperature[°C]  DewPoint[°C]  Rainfall DayType  HH
# 0          0.0    30.070           12.500        11.110       0.0     Sun  00
# 1          0.0    30.025           11.665        10.000       0.0     Sun  01
# 2          0.0    29.995           11.110        10.000       0.0     Sun  02
# 3          0.0    29.970           11.110        10.000       0.0     Sun  03
# 4          0.0    29.915           11.110        10.000       0.0     Sun  04
# ..         ...       ...              ...           ...       ...     ...  ..
# 177        0.0    29.340            7.780         3.890       0.0     Sat  20
# 178        0.0    29.340            7.500         3.890       0.0     Sat  21
# 179        0.0    29.340            7.500         3.890       0.0     Sat  21
# 180        0.0    29.340            7.500         4.445       0.0     Sat  22
# 181        0.0    29.340            7.220         5.000       0.2     Sat  23
#
# [182 rows x 12 columns]

# %%
weather_compl.drop(["Temperature [F]","DewPoint [F]","Humidity","Wind Gust","Pressure"],axis=1, inplace=True)
weather_compl.head(10)
# Out:
#              datetime  Wind Speed  Temperature[°C]  DewPoint[°C]  Rainfall  \
# 0 2009-11-01 00:00:00         5.0           12.500        11.110       0.0
# 1 2009-11-01 01:00:00         1.0           11.665        10.000       0.0
# 2 2009-11-01 02:00:00         1.5           11.110        10.000       0.0
# 3 2009-11-01 03:00:00         4.0           11.110        10.000       0.0
# 4 2009-11-01 04:00:00         4.5           11.110        10.000       0.0
# 5 2009-11-01 05:00:00         6.5           11.945        10.555       0.0
# 6 2009-11-01 06:00:00        13.0           12.780        11.110       0.0
# 7 2009-11-01 07:00:00        14.0           12.780        11.665       0.0
# 8 2009-11-01 08:00:00        14.0           14.445        12.500       0.2
# 9 2009-11-01 09:00:00        17.0           15.000        12.780       0.2
#
#   DayType  HH
# 0     Sun  00
# 1     Sun  01
# 2     Sun  02
# 3     Sun  03
# 4     Sun  04
# 5     Sun  05
# 6     Sun  06
# 7     Sun  07
# 8     Sun  08
# 9     Sun  09

# %%
weather_compl = weather_compl.rename(columns={'Hour':'HH'})
weather_compl
# Out:
#                datetime  Wind Speed  Temperature[°C]  DewPoint[°C]  Rainfall  \
# 0   2009-11-01 00:00:00         5.0           12.500        11.110       0.0
# 1   2009-11-01 01:00:00         1.0           11.665        10.000       0.0
# 2   2009-11-01 02:00:00         1.5           11.110        10.000       0.0
# 3   2009-11-01 03:00:00         4.0           11.110        10.000       0.0
# 4   2009-11-01 04:00:00         4.5           11.110        10.000       0.0
# ..                  ...         ...              ...           ...       ...
# 177 2009-11-07 20:00:00         8.5            7.780         3.890       0.0
# 178 2009-11-07 21:00:00         7.5            7.500         3.890       0.0
# 179 2009-11-07 21:00:00         7.5            7.500         3.890       0.0
# 180 2009-11-07 22:00:00         6.5            7.500         4.445       0.0
# 181 2009-11-07 23:00:00         5.0            7.220         5.000       0.2
#
#     DayType  HH
# 0       Sun  00
# 1       Sun  01
# 2       Sun  02
# 3       Sun  03
# 4       Sun  04
# ..      ...  ..
# 177     Sat  20
# 178     Sat  21
# 179     Sat  21
# 180     Sat  22
# 181     Sat  23
#
# [182 rows x 7 columns]

# %%
## connect weather data with train data

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521656 entries, 0 to 521655
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     521656 non-null  int64
#  1   DayType        521656 non-null  object
#  2   SubSystem      521656 non-null  object
#  3   StartStn       521656 non-null  object
#  4   EndStn         521656 non-null  object
#  5   EntTime        521656 non-null  int64
#  6   EntTimeHHMM    521656 non-null  object
#  7   ExTime         521656 non-null  int64
#  8   ExTimeHHMM     521656 non-null  object
#  9   JourneyLength  521656 non-null  int64
#  10  StartLat       521656 non-null  float64
#  11  StartLong      521656 non-null  float64
#  12  EndLat         521656 non-null  float64
#  13  EndLong        521656 non-null  float64
#  14  HH             521656 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 59.7+ MB

# %%
weather_compl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 181
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         182 non-null    datetime64[ns]
#  1   Wind Speed       178 non-null    float64
#  2   Temperature[°C]  178 non-null    float64
#  3   DewPoint[°C]     178 non-null    float64
#  4   Rainfall         182 non-null    float64
#  5   DayType          182 non-null    object
#  6   HH               182 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 11.4+ KB

# %%
combined["HH"] = combined["EntTimeHHMM"].str[0:2]
combined.head()
# Out:
#   DayType SubSystem       StartStn         EndStn  EntTime EntTimeHHMM  \
# 0     Wed       LUL  Goodge Street  Charing Cross     1000       16:40
# 1     Fri       LUL  Goodge Street  Charing Cross     1000       16:40
# 2     Wed       LUL  Goodge Street  Charing Cross     1004       16:44
# 3     Mon       LUL  Goodge Street  Charing Cross     1005       16:45
# 4     Thu       LUL  Goodge Street  Charing Cross     1006       16:46
#
#    ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong     EndLat  \
# 0    1010      16:50             10  51.520613  -0.134808  51.508359
# 1    1011      16:51             11  51.520613  -0.134808  51.508359
# 2    1013      16:53              9  51.520613  -0.134808  51.508359
# 3    1013      16:53              8  51.520613  -0.134808  51.508359
# 4    1014      16:54              8  51.520613  -0.134808  51.508359
#
#     EndLong  HH
# 0 -0.124803  16
# 1 -0.124803  16
# 2 -0.124803  16
# 3 -0.124803  16
# 4 -0.124803  16

# %%
weather_compl.set_index('datetime')
# Out:
#                      Wind Speed  Temperature[°C]  DewPoint[°C]  Rainfall  \
# datetime
# 2009-11-01 00:00:00         5.0           12.500        11.110       0.0
# 2009-11-01 01:00:00         1.0           11.665        10.000       0.0
# 2009-11-01 02:00:00         1.5           11.110        10.000       0.0
# 2009-11-01 03:00:00         4.0           11.110        10.000       0.0
# 2009-11-01 04:00:00         4.5           11.110        10.000       0.0
# ...                         ...              ...           ...       ...
# 2009-11-07 20:00:00         8.5            7.780         3.890       0.0
# 2009-11-07 21:00:00         7.5            7.500         3.890       0.0
# 2009-11-07 21:00:00         7.5            7.500         3.890       0.0
# 2009-11-07 22:00:00         6.5            7.500         4.445       0.0
# 2009-11-07 23:00:00         5.0            7.220         5.000       0.2
#
#                     DayType  HH
# datetime
# 2009-11-01 00:00:00     Sun  00
# 2009-11-01 01:00:00     Sun  01
# 2009-11-01 02:00:00     Sun  02
# 2009-11-01 03:00:00     Sun  03
# 2009-11-01 04:00:00     Sun  04
# ...                     ...  ..
# 2009-11-07 20:00:00     Sat  20
# 2009-11-07 21:00:00     Sat  21
# 2009-11-07 21:00:00     Sat  21
# 2009-11-07 22:00:00     Sat  22
# 2009-11-07 23:00:00     Sat  23
#
# [182 rows x 6 columns]

# %%
#firstweek = combined[:182]
#firstweek

# %%
train_weather = pd.merge(train,weather_compl,how="left",left_on=["HH","DayType"], right_on=["HH","DayType"])
train_weather.head()
# Out:
#    Unnamed: 0 DayType SubSystem       StartStn         EndStn  EntTime  \
# 0           0     Wed       LUL  Goodge Street  Charing Cross     1000
# 1           1     Fri       LUL  Goodge Street  Charing Cross     1000
# 2           2     Wed       LUL  Goodge Street  Charing Cross     1004
# 3           3     Mon       LUL  Goodge Street  Charing Cross     1005
# 4           4     Thu       LUL  Goodge Street  Charing Cross     1006
#
#   EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength   StartLat  StartLong  \
# 0       16:40    1010      16:50             10  51.520613  -0.134808
# 1       16:40    1011      16:51             11  51.520613  -0.134808
# 2       16:44    1013      16:53              9  51.520613  -0.134808
# 3       16:45    1013      16:53              8  51.520613  -0.134808
# 4       16:46    1014      16:54              8  51.520613  -0.134808
#
#       EndLat   EndLong  HH            datetime  Wind Speed  Temperature[°C]  \
# 0  51.508359 -0.124803  16 2009-11-04 16:00:00        12.0           10.555
# 1  51.508359 -0.124803  16 2009-11-06 16:00:00        10.5           11.665
# 2  51.508359 -0.124803  16 2009-11-04 16:00:00        12.0           10.555
# 3  51.508359 -0.124803  16 2009-11-02 16:00:00        11.0           11.110
# 4  51.508359 -0.124803  16 2009-11-05 16:00:00        13.0           12.220
#
#    DewPoint[°C]  Rainfall
# 0         5.000       0.2
# 1         7.500       0.0
# 2         5.000       0.2
# 3         3.335       0.0
# 4         5.000       0.0

# %%
train_weather['HH'].value_counts()
# Out:
# 09    64646
# 08    58495
# 17    56735
# 18    49477
# 07    39620
# 16    37665
# 21    32632
# 19    29152
# 15    28324
# 14    23141
# 13    23028
# 12    22182
# 20    20003
# 10    19969
# 11    19463
# 06    15408
# 22    14204
# 23    10384
# 05     3490
# 24     2255
# 04       21
# 25        1
# Name: HH, dtype: int64

# %%
#train_weather.drop("DayType",axis=1, inplace=True)
#train_weather.head(10)

# %%
train_weather.drop(train_weather.columns[0], axis= 1, inplace = True)

# %%
train_weather.set_index('datetime')
# Out:
#                     DayType SubSystem       StartStn         EndStn  EntTime  \
# datetime
# 2009-11-04 16:00:00     Wed       LUL  Goodge Street  Charing Cross     1000
# 2009-11-06 16:00:00     Fri       LUL  Goodge Street  Charing Cross     1000
# 2009-11-04 16:00:00     Wed       LUL  Goodge Street  Charing Cross     1004
# 2009-11-02 16:00:00     Mon       LUL  Goodge Street  Charing Cross     1005
# 2009-11-05 16:00:00     Thu       LUL  Goodge Street  Charing Cross     1006
# ...                     ...       ...            ...            ...      ...
# 2009-11-04 17:00:00     Wed       LUL        Croxley        Croxley     1048
# 2009-11-07 18:00:00     Sat       LUL        Croxley        Croxley     1105
# 2009-11-03 16:00:00     Tue       LUL    Chorleywood        Croxley     1007
# 2009-11-04 18:00:00     Wed       LUL    Chorleywood        Croxley     1113
# 2009-11-03 11:00:00     Tue       LUL    West Harrow        Croxley      686
#
#                     EntTimeHHMM  ExTime ExTimeHHMM  JourneyLength   StartLat  \
# datetime
# 2009-11-04 16:00:00       16:40    1010      16:50             10  51.520613
# 2009-11-06 16:00:00       16:40    1011      16:51             11  51.520613
# 2009-11-04 16:00:00       16:44    1013      16:53              9  51.520613
# 2009-11-02 16:00:00       16:45    1013      16:53              8  51.520613
# 2009-11-05 16:00:00       16:46    1014      16:54              8  51.520613
# ...                         ...     ...        ...            ...        ...
# 2009-11-04 17:00:00       17:28    1048      17:28              0  51.647005
# 2009-11-07 18:00:00       18:25    1216      20:16            111  51.647005
# 2009-11-03 16:00:00       16:47    1034      17:14             27  51.654266
# 2009-11-04 18:00:00       18:33    1131      18:51             18  51.654266
# 2009-11-03 11:00:00       11:26     721      12:01             35  51.578924
#
#                      StartLong     EndLat   EndLong  HH  Wind Speed  \
# datetime
# 2009-11-04 16:00:00  -0.134808  51.508359 -0.124803  16        12.0
# 2009-11-06 16:00:00  -0.134808  51.508359 -0.124803  16        10.5
# 2009-11-04 16:00:00  -0.134808  51.508359 -0.124803  16        12.0
# 2009-11-02 16:00:00  -0.134808  51.508359 -0.124803  16        11.0
# 2009-11-05 16:00:00  -0.134808  51.508359 -0.124803  16        13.0
# ...                        ...        ...       ...  ..         ...
# 2009-11-04 17:00:00  -0.441604  51.647005 -0.441604  17         7.5
# 2009-11-07 18:00:00  -0.441604  51.647005 -0.441604  18         7.0
# 2009-11-03 16:00:00  -0.518334  51.647005 -0.441604  16        15.0
# 2009-11-04 18:00:00  -0.518334  51.647005 -0.441604  18        11.0
# 2009-11-03 11:00:00  -0.353847  51.647005 -0.441604  11        13.5
#
#                      Temperature[°C]  DewPoint[°C]  Rainfall
# datetime
# 2009-11-04 16:00:00           10.555         5.000       0.2
# 2009-11-06 16:00:00           11.665         7.500       0.0
# 2009-11-04 16:00:00           10.555         5.000       0.2
# 2009-11-02 16:00:00           11.110         3.335       0.0
# 2009-11-05 16:00:00           12.220         5.000       0.0
# ...                              ...           ...       ...
# 2009-11-04 17:00:00           10.000         6.110       0.0
# 2009-11-07 18:00:00            8.335         3.890       0.0
# 2009-11-03 16:00:00           12.220         6.110       0.0
# 2009-11-04 18:00:00           10.000         6.110       0.0
# 2009-11-03 11:00:00           13.890        10.555       0.0
#
# [570295 rows x 18 columns]

# %%
train_weather.to_csv('week1_train.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=4, figsize=(14,8))
sns.distplot(train_weather["HH"], kde=True, ax=axs[0])
sns.distplot(train_weather["Temperature[°C]"], kde=True, ax=axs[1])
sns.distplot(train_weather['HH'].value_counts(), kde=True, ax=axs[3])
sns.distplot(train_weather['Rainfall'].value_counts(), kde=True, ax=axs[2])
# Out:
# C:\Users\sandr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sandr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sandr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sandr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=train_weather, x="HH", y="Temperature[°C]", s=100, color=".2", marker="+")

# %%
sns.displot(x=train_weather["HH"], y=train_weather["Temperature[°C]"],binwidth=(2, .5))
